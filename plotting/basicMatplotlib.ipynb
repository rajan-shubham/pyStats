# %%
import matplotlib.pyplot as plt
y = [98, 67, 88, 95, 88]
x = ["Part1", "Part2", "Part3", "Part4", "Part5"]

plt.bar(x, y)
plt.xlabel("Parts of Harry Potter", fontsize=16)
plt.ylabel("Popularity")
plt.title("Popularity of Diff. parts of Harry Potter")
plt.show()
